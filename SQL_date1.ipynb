# %%
import sqlite3

# %%
import pandas as pd

# %%
conn=sqlite3.connect('test.db')

# %%
conn.execute(
'''
CREATE TABLE IF NOT EXISTS students(
id INTEGER,
    name TEXT,
    age INTERGER,
    score INTEGER
    )
    
''')

# %%
conn.execute("INSERT INTO.students VALUES (1, 'A', 23, 88)")
# Out:
# ------------------------------------------------------------
# OperationalError           Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 conn.execute("INSERT INTO.students VALUES (1, 'A', 23, 88)")
#
# OperationalError: near ".": syntax error

# %%
conn.execute("INSERT INTO students VALUES (1, 'A', 23, 88)")

# %%
conn.execute("INSERT INTO students VALUES (2, 'B', 44, 99)")

# %%
conn.execute("INSERT INTO students VALUES (3, 'C', 55, 77)")

# %%
conn.execute("INSERT INTO students VALUES (4, 'D', 66, 55)")

# %%
pd.read_sql('SELECT * FROM students',conn)
# Out:
#    id name  age  score
# 0   1    A   23     88
# 1   2    B   44     99
# 2   3    C   55     77
# 3   4    D   66     55

# %%
pd.read_sql('SELECT name, score FROM students', conn)
# Out:
#   name  score
# 0    A     88
# 1    B     99
# 2    C     77
# 3    D     55

# %%
result=pd.read_sql('SELECT * FROM students ORDER BY score DESC', conn)
print(result)
print("行数",len(result))
# Out:
# Empty DataFrame
# Columns: [id, name, age, score]
# Index: []
# 行数 0

# %%
pd.read_sql('SELECT * FROM students ORDER BY score', conn)
# Out:
# Empty DataFrame
# Columns: [id, name, age, score]
# Index: []

# %%
pd.read_sql('SELECT * FROM students WHERE score > 90', conn)
# Out:
# Empty DataFrame
# Columns: [id, name, age, score]
# Index: []

# %%
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn)
# Out:
#        name
# 0  students

# %%
conn.execute("DELETE FROM students")  # 清空，避免重复

conn.execute("INSERT INTO students VALUES (1, 'A', 23, 88)")
conn.execute("INSERT INTO students VALUES (2, 'B', 25, 99)")
conn.execute("INSERT INTO students VALUES (3, 'C', 22, 77)")
conn.execute("INSERT INTO students VALUES (4, 'D', 28, 55)")
conn.commit()

# %%
print(conn.commit())
# Out:
# None

# %%
pd.read_sql('SELECT * FROM students', conn)
# Out:
#    id name  age  score
# 0   1    A   23     88
# 1   2    B   25     99
# 2   3    C   22     77
# 3   4    D   28     55

# %%
df.to_sql('students', conn, if_exists='replace', index=False)
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df.to_sql('students', conn, if_exists='replace', index=False)
#       2
#
# NameError: name 'df' is not defined

# %%
pd.read_sql('SELECT name, score FROM students', conn)
# Out:
#   name  score
# 0    A     88
# 1    B     99
# 2    C     77
# 3    D     55

# %%
pd.read_sql('SELECT * FROM students WHERE score>85', conn)
# Out:
#    id name  age  score
# 0   1    A   23     88
# 1   2    B   25     99

# %%
pd.read_sql('SELECT * FROM students ORDER BY  score DESC', conn)
# Out:
#    id name  age  score
# 0   2    B   25     99
# 1   1    A   23     88
# 2   3    C   22     77
# 3   4    D   28     55
